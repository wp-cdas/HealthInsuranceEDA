# %% [markdown]
# ## Loading using Pandas

# %% [markdown]
# If programming in Python 3, you can load use a variety of packages to load the CSV data files we have available.  We will demonstrate one of the most popular here: pandas.

# %%
import pandas as pd

# %%
network = pd.read_csv('/data/PDSI/Network.csv')

# %%
network
# Out:
#       BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0             2014        AK     21989       HIOS           6
# 1             2014        AK     38344       HIOS           6
# 2             2014        AK     38536       HIOS           2
# 3             2014        AK     42507       HIOS           3
# 4             2014        AK     73836       HIOS           6
# ...            ...       ...       ...        ...         ...
# 3817          2016        WV     75441      SERFF           2
# 3818          2016        WV     76526      SERFF           4
# 3819          2016        WV     76526      SERFF           4
# 3820          2016        WV     94562      SERFF           2
# 3821          2016        WV     96480      SERFF           2
#
#                ImportDate  IssuerId2 StateCode2             NetworkName  \
# 0     2014-03-19 07:06:49      21989         AK             ODS Premier
# 1     2013-08-28 08:15:53      38344         AK            HeritagePlus
# 2     2013-08-01 12:48:00      38536         AK  Lincoln Dental Connect
# 3     2013-09-02 11:39:25      42507         AK   DentalGuard Preferred
# 4     2014-04-18 11:49:29      73836         AK   Moda Plus AK Regional
# ...                   ...        ...        ...                     ...
# 3817  2015-08-20 12:28:36      75441         WV           DenteMax, LLC
# 3818  2015-08-20 12:28:36      76526         WV        Delta Dental PPO
# 3819  2015-08-20 12:28:36      76526         WV        Delta Dental PPO
# 3820  2015-08-20 12:28:36      94562         WV                PDP PLUS
# 3821  2015-08-20 12:28:36      96480         WV   DentalGuard Preferred
#
#      NetworkId                                         NetworkURL  RowNumber  \
# 0       AKN001  https://www.modahealth.com/ProviderSearch/face...         13
# 1       AKN001                https://www.premera.com/wa/visitor/         13
# 2       AKN001  http://lfg.go2dental.com/member/dental_search/...         13
# 3       AKN001  https://www.guardiananytime.com/fpapp/FPWeb/de...         13
# 4       AKN001  https://www.modahealth.com/ProviderSearch/face...         13
# ...        ...                                                ...        ...
# 3817    WVN001                                   www.dentemax.com         13
# 3818    WVN001      https://www.deltadentalins.com/find-a-dentist         13
# 3819    WVN001      https://www.deltadentalins.com/find-a-dentist         13
# 3820    WVN001  https://metlocator.metlife.com/metlocator/exec...         13
# 3821    WVN001  https://www.guardiananytime.com/fpapp/FPWeb/de...         13
#
#           MarketCoverage DentalOnlyPlan
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ...                  ...            ...
# 3817  SHOP (Small Group)            Yes
# 3818  SHOP (Small Group)            Yes
# 3819          Individual            Yes
# 3820  SHOP (Small Group)            Yes
# 3821  SHOP (Small Group)            Yes
#
# [3822 rows x 14 columns]

# %% [markdown]
# There are a lot more attributes you can set for the "read_csv" method but the defaults do a pretty good job.  You can read more here:
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %% [markdown]
# ## Moving around the filesystem

# %% [markdown]
# To provide further examples of how to access the data files on the DSP, you'll find a couple examples of working the Python's "os" package below.

# %%
import os

# %%
os.listdir('/data/PDSI')
# Out:
# ['health-insurance-marketplace.zip',
#  'Crosswalk2015.csv',
#  'raw',
#  'ServiceArea.csv',
#  'Rate.csv',
#  'database.sqlite',
#  'BusinessRules.csv',
#  'PlanAttributes.csv',
#  'BenefitsCostSharing.csv',
#  'hashes.txt',
#  'Crosswalk2016.csv',
#  'Network.csv']

# %%
for root, dirs, files in os.walk('/data/PDSI'):
    print('Root:' + root)
    print('Directories:')
    print(dirs)
    print('Files:')
    print(files)
    print('--------------------')
# Out:
# Root:/data/PDSI
# Directories:
# ['raw']
# Files:
# ['health-insurance-marketplace.zip', 'Crosswalk2015.csv', 'ServiceArea.csv', 'Rate.csv', 'database.sqlite', 'BusinessRules.csv', 'PlanAttributes.csv', 'BenefitsCostSharing.csv', 'hashes.txt', 'Crosswalk2016.csv', 'Network.csv']
# --------------------
# Root:/data/PDSI/raw
# Directories:
# ['2016', '2014', '2015']
# Files:
# ['Business_Rules_PUF.csv', '._Service_Area_PUF.csv', '._Plan_Attributes_PUF_2015-12-08.csv', '00Tree.html', 'Benefits_Cost_Sharing_PUF_2015-12-08.csv', 'Plan_Attributes_PUF_2015-12-08.csv', '._Plan_Crosswalk_PUF_2014-12-22.csv', '.sentinel', 'Network_PUF.csv', '._Plan_Attributes_PUF.csv', 'Rate_PUF.csv', '._Rate_PUF_2015-12-08.csv', 'Plan_ID_Crosswalk_PUF_2015-12-07.CSV', 'Business_Rules_PUF_2015-12-08.csv', '._Plan_Attributes_PUF_2014_2015-03-09.csv', 'Plan_Crosswalk_PUF_2014-12-22.csv', 'Plan_Attributes_PUF.csv', '._Machine_Readable_PUF_2015-12-21.xlsx', '._Network_PUF.csv', '._Network_PUF_2015-12-08.csv', 'Service_Area_PUF.csv', '._Rate_PUF.csv', 'Benefits_Cost_Sharing_PUF.csv', '._Plan_ID_Crosswalk_PUF_2015-12-07.CSV', '._2016', 'Plan_Attributes_PUF_2014_2015-03-09.csv', 'Network_PUF_2015-12-08.csv', '._Business_Rules_PUF_Reformat.csv', 'Rate_PUF_2015-12-08.csv', 'Business_Rules_PUF_Reformat.csv', '._ServiceArea_PUF_2015-12-08.csv', '._.sentinel', '._Business_Rules_PUF_2015-12-08.csv', '._Benefits_Cost_Sharing_PUF.csv', '._2015', '._2014', 'Machine_Readable_PUF_2015-12-21.xlsx', '._Business_Rules_PUF.csv', 'ServiceArea_PUF_2015-12-08.csv', '._Benefits_Cost_Sharing_PUF_2015-12-08.csv']
# --------------------
# Root:/data/PDSI/raw/2016
# Directories:
# []
# Files:
# ['Benefits_Cost_Sharing_PUF_2015-12-08.csv', 'Plan_Attributes_PUF_2015-12-08.csv', '.sentinel', 'Plan_ID_Crosswalk_PUF_2015-12-07.CSV', 'Business_Rules_PUF_2015-12-08.csv', 'Network_PUF_2015-12-08.csv', 'Rate_PUF_2015-12-08.csv', 'Machine_Readable_PUF_2015-12-21.xlsx', 'ServiceArea_PUF_2015-12-08.csv']
# --------------------
# Root:/data/PDSI/raw/2014
# Directories:
# []
# Files:
# ['Business_Rules_PUF.csv', '.sentinel', 'Network_PUF.csv', 'Rate_PUF.csv', 'Service_Area_PUF.csv', 'Benefits_Cost_Sharing_PUF.csv', 'Plan_Attributes_PUF_2014_2015-03-09.csv']
# --------------------
# Root:/data/PDSI/raw/2015
# Directories:
# []
# Files:
# ['.sentinel', 'Network_PUF.csv', 'Rate_PUF.csv', 'Plan_Crosswalk_PUF_2014-12-22.csv', 'Plan_Attributes_PUF.csv', 'Service_Area_PUF.csv', 'Benefits_Cost_Sharing_PUF.csv', 'Business_Rules_PUF_Reformat.csv']
# --------------------

# %%
for root, dirs, files in os.walk('/data/PDSI'):
    for file in files:
        if os.path.splitext(file)[1] == '.csv':
            print(file)
# Out:
# Crosswalk2015.csv
# ServiceArea.csv
# Rate.csv
# BusinessRules.csv
# PlanAttributes.csv
# BenefitsCostSharing.csv
# Crosswalk2016.csv
# Network.csv
# Business_Rules_PUF.csv
# ._Service_Area_PUF.csv
# ._Plan_Attributes_PUF_2015-12-08.csv
# Benefits_Cost_Sharing_PUF_2015-12-08.csv
# Plan_Attributes_PUF_2015-12-08.csv
# ._Plan_Crosswalk_PUF_2014-12-22.csv
# Network_PUF.csv
# ._Plan_Attributes_PUF.csv
# Rate_PUF.csv
# ._Rate_PUF_2015-12-08.csv
# Business_Rules_PUF_2015-12-08.csv
# ._Plan_Attributes_PUF_2014_2015-03-09.csv
# Plan_Crosswalk_PUF_2014-12-22.csv
# Plan_Attributes_PUF.csv
# ._Network_PUF.csv
# ._Network_PUF_2015-12-08.csv
# Service_Area_PUF.csv
# ._Rate_PUF.csv
# Benefits_Cost_Sharing_PUF.csv
# Plan_Attributes_PUF_2014_2015-03-09.csv
# Network_PUF_2015-12-08.csv
# ._Business_Rules_PUF_Reformat.csv
# Rate_PUF_2015-12-08.csv
# Business_Rules_PUF_Reformat.csv
# ._ServiceArea_PUF_2015-12-08.csv
# ._Business_Rules_PUF_2015-12-08.csv
# ._Benefits_Cost_Sharing_PUF.csv
# ._Business_Rules_PUF.csv
# ServiceArea_PUF_2015-12-08.csv
# ._Benefits_Cost_Sharing_PUF_2015-12-08.csv
# Benefits_Cost_Sharing_PUF_2015-12-08.csv
# Plan_Attributes_PUF_2015-12-08.csv
# Business_Rules_PUF_2015-12-08.csv
# Network_PUF_2015-12-08.csv
# Rate_PUF_2015-12-08.csv
# ServiceArea_PUF_2015-12-08.csv
# Business_Rules_PUF.csv
# Network_PUF.csv
# Rate_PUF.csv
# Service_Area_PUF.csv
# Benefits_Cost_Sharing_PUF.csv
# Plan_Attributes_PUF_2014_2015-03-09.csv
# Network_PUF.csv
# Rate_PUF.csv
# Plan_Crosswalk_PUF_2014-12-22.csv
# Plan_Attributes_PUF.csv
# Service_Area_PUF.csv
# Benefits_Cost_Sharing_PUF.csv
# Business_Rules_PUF_Reformat.csv
